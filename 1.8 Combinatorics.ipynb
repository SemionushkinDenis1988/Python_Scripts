# %%
from IPython.display import Image #display picture
Image('Combinatorics.png')

# %%
from IPython.display import Image #display picture
Image('combination-35a.png')

# %%
import scipy
scipy.special.binom(13,3)
# Out:
# 286.0

# %%
scipy.special.binom(7,2)
# Out:
# 21.0

# %%
scipy.special.binom(20,5)
# Out:
# 15504.0
